# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import os

sys.path.append("/media/dean/datastore/datasets/ObjectDetection-OneStageDet/yolo")

import detect

# %%
yolo_dir = '/media/dean/datastore/datasets/ObjectDetection-OneStageDet/yolo/'
weights_file = os.path.join(yolo_dir, 'outputs/Yolov3/baseline/weights/backup.pt')
cfgs_root = os.path.join(yolo_dir, 'cfgs')
img_dir = '/home/dean/Desktop/testing_imgs/'

r = detect.Yolov3Annotator(weights_file = weights_file, cfgs_root = cfgs_root)

anns = r.annotate(img_dir)
print(anns)
# Out:
# Initializing Annotation Pipeline ... \o/ \o/ ...
# ...
